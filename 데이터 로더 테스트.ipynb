# %%
a = []
a.append(1)
print(a)
a.append(2)
print(a)
a.append(3)
print(a)
# Out:
# [1]
# [1, 2]
# [1, 2, 3]

# %%
import imp

from data_loader import medical_segmentation_data_loader
imp.reload(medical_segmentation_data_loader)
from data_loader.medical_segmentation_data_loader import DataLoader

# %%
data_loader = DataLoader(dataset_name="tumor", img_res=(512, 512))

# %%
data_gen = data_loader.load_all(on_memory=False)

# %%
data = next(data_gen)

image_array = (data[0]*127.5)
mask_array = data[1]

# %%
from matplotlib import pyplot as plt

plt.imshow(image_array)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(temp_masked)
plt.show()

# %%
a =0

for i in range(a,5):
    a = i 
    print("ee")
# Out:
# ee
# ee
# ee
# ee
# ee
